# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('training_set_rel3.xls')

# %%
df = df1[df1['essay_set']==1]

# %%
df = df.sample(frac=0.1,random_state=10)

# %%
df
# Out:
#       essay_id  essay_set                                              essay  \
# 245        246          1  Dear editor, Have you ever would to know somet...
# 612        615          1  Computers should be for everyone! Dont you thi...
# 1084      1087          1  You say that computers are bad on todays socie...
# 708        711          1  Dear editor, Have you ever stopped and asked y...
# 1155      1159          1  In a study conducted by @ORGANIZATION1, @NUM1 ...
# 689        692          1  I don't think that computers is the most posit...
# 1775      1780          1  Dear Newspaper I think that computers were one...
# 1175      1179          1  I believe that people spending to much time on...
# 491        494          1  Dear Newspaper, @CAPS1 generation has grown up...
# 176        177          1  Dear @LOCATION1 @CAPS1, I strongly believe tha...
# 315        317          1  Dear @CAPS1, @CAPS2 do people benefit from the...
# ...

# %%
df
# Out:
#       essay_id  essay_set                                              essay  \
# 245        246          1  Dear editor, Have you ever would to know somet...
# 612        615          1  Computers should be for everyone! Dont you thi...
# 1084      1087          1  You say that computers are bad on todays socie...
# 708        711          1  Dear editor, Have you ever stopped and asked y...
# 1155      1159          1  In a study conducted by @ORGANIZATION1, @NUM1 ...
# 689        692          1  I don't think that computers is the most posit...
# 1775      1780          1  Dear Newspaper I think that computers were one...
# 1175      1179          1  I believe that people spending to much time on...
# 491        494          1  Dear Newspaper, @CAPS1 generation has grown up...
# 176        177          1  Dear @LOCATION1 @CAPS1, I strongly believe tha...
# 315        317          1  Dear @CAPS1, @CAPS2 do people benefit from the...
# ...
