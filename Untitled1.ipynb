# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.Series([2,3,4,5,6],dtype='int8')

# %%
data
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int8

# %%
data.values
# Out:
# array([2, 3, 4, 5, 6], dtype=int8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
data[1]
# Out:
# 3

# %%
data[1:3]
# Out:
# 1    3
# 2    4
# dtype: int8

# %%
data
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int8

# %%
data = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])

# %%
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
population_dict = {'California': 38332521,
'Texas': 26448193,
'New York': 19651127,
'Florida': 19552860,
'Illinois': 12882135}

# %%
import pandas as pd

# %%
population=pd.Series(population_dict)
population
# Out:
# California    38332521
# Florida       19552860
# Illinois      12882135
# New York      19651127
# Texas         26448193
# dtype: int64

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
'Florida': 170312, 'Illinois': 149995,'Dhaka':4599}

# %%
area = pd.Series(area_dict)

# %%
area
# Out:
# California    423967
# Dhaka           4599
# Florida       170312
# Illinois      149995
# New York      141297
# Texas         695662
# dtype: int64

# %%
states = pd.DataFrame({'populations':population,'areas':area})

# %%
states
# Out:
#              areas  populations
# California  423967   38332521.0
# Dhaka         4599          NaN
# Florida     170312   19552860.0
# Illinois    149995   12882135.0
# New York    141297   19651127.0
# Texas       695662   26448193.0

# %%
import numpy as np

# %%
states.index
# Out:
# Index(['California', 'Dhaka', 'Florida', 'Illinois', 'New York', 'Texas'], dtype='object')

# %%
states.columns
# Out:
# Index(['areas', 'populations'], dtype='object')

# %%
states['areas']
# Out:
# California    423967
# Dhaka           4599
# Florida       170312
# Illinois      149995
# New York      141297
# Texas         695662
# Name: areas, dtype: int64

# %%
states['populations']
# Out:
# California    38332521.0
# Dhaka                NaN
# Florida       19552860.0
# Illinois      12882135.0
# New York      19651127.0
# Texas         26448193.0
# Name: populations, dtype: float64

# %%
population
# Out:
# California    38332521
# Florida       19552860
# Illinois      12882135
# New York      19651127
# Texas         26448193
# dtype: int64

# %%
pd.DataFrame(population,columns=['population'])
# Out:
#             population
# California    38332521
# Florida       19552860
# Illinois      12882135
# New York      19651127
# Texas         26448193

# %%
pd.DataFrame({'population': population})
# Out:
#             population
# California    38332521
# Florida       19552860
# Illinois      12882135
# New York      19651127
# Texas         26448193

# %%
data = [{'a':i,'b':2*i} for i in range(3)]

# %%
data
# Out:
# [{'a': 0, 'b': 0}, {'a': 1, 'b': 2}, {'a': 2, 'b': 4}]

# %%
pd.DataFrame(data)
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
pd.DataFrame(np.random.rand(3,2),columns=['foo','bar'],index=[1,2,3])
# Out:
#         foo       bar
# 1  0.873589  0.854032
# 2  0.190850  0.730043
# 3  0.722939  0.971687

# %%
data
# Out:
# [{'a': 0, 'b': 0}, {'a': 1, 'b': 2}, {'a': 2, 'b': 4}]

# %%
states
# Out:
#              areas  populations
# California  423967   38332521.0
# Dhaka         4599          NaN
# Florida     170312   19552860.0
# Illinois    149995   12882135.0
# New York    141297   19651127.0
# Texas       695662   26448193.0

# %%
states['density']=states['areas']/states['populations']

# %%
states
# Out:
#              areas  populations   density
# California  423967   38332521.0  0.011060
# Dhaka         4599          NaN       NaN
# Florida     170312   19552860.0  0.008710
# Illinois    149995   12882135.0  0.011644
# New York    141297   19651127.0  0.007190
# Texas       695662   26448193.0  0.026303

# %%
states.values
# Out:
# array([[  4.23967000e+05,   3.83325210e+07,   1.10602431e-02],
#        [  4.59900000e+03,              nan,              nan],
#        [  1.70312000e+05,   1.95528600e+07,   8.71033700e-03],
#        [  1.49995000e+05,   1.28821350e+07,   1.16436445e-02],
#        [  1.41297000e+05,   1.96511270e+07,   7.19027463e-03],
#        [  6.95662000e+05,   2.64481930e+07,   2.63028177e-02]])

# %%
states
# Out:
#              areas  populations   density
# California  423967   38332521.0  0.011060
# Dhaka         4599          NaN       NaN
# Florida     170312   19552860.0  0.008710
# Illinois    149995   12882135.0  0.011644
# New York    141297   19651127.0  0.007190
# Texas       695662   26448193.0  0.026303

# %%
states.T
# Out:
#                California   Dhaka       Florida      Illinois      New York  \
# areas        4.239670e+05  4599.0  1.703120e+05  1.499950e+05  1.412970e+05
# populations  3.833252e+07     NaN  1.955286e+07  1.288214e+07  1.965113e+07
# density      1.106024e-02     NaN  8.710337e-03  1.164364e-02  7.190275e-03
#
#                     Texas
# areas        6.956620e+05
# populations  2.644819e+07
# density      2.630282e-02

# %%
a=states.T

# %%
a
# Out:
#                California   Dhaka       Florida      Illinois      New York  \
# areas        4.239670e+05  4599.0  1.703120e+05  1.499950e+05  1.412970e+05
# populations  3.833252e+07     NaN  1.955286e+07  1.288214e+07  1.965113e+07
# density      1.106024e-02     NaN  8.710337e-03  1.164364e-02  7.190275e-03
#
#                     Texas
# areas        6.956620e+05
# populations  2.644819e+07
# density      2.630282e-02

# %%
a.values
# Out:
# array([[  4.23967000e+05,   4.59900000e+03,   1.70312000e+05,
#           1.49995000e+05,   1.41297000e+05,   6.95662000e+05],
#        [  3.83325210e+07,              nan,   1.95528600e+07,
#           1.28821350e+07,   1.96511270e+07,   2.64481930e+07],
#        [  1.10602431e-02,              nan,   8.71033700e-03,
#           1.16436445e-02,   7.19027463e-03,   2.63028177e-02]])

# %%
a.values[0]
# Out:
# array([ 423967.,    4599.,  170312.,  149995.,  141297.,  695662.])

# %%
a.values[0][1]
# Out:
# 4599.0

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('classic')

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
# ...

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.show()
