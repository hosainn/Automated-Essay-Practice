# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
k = range(1,11)

# %%
k
# Out:
# range(1, 11)

# %%
y = [0.1,0.3,0.5,0.5,0.6,0.78,0.2,0.32,0.45,0.04]
len(y)
# Out:
# 10

# %%
plt.plot(k,y)
plt.xlabel('value of k like x')
plt.ylabel('value of y like y')
# Out:
# Text(0,0.5,'value of y like y')

# %%
a =[]

# %%
a.append(1)

# %%
a.append(0)

# %%
a
# Out:
# [1, 0]
